# %% [markdown]
# # Jaguar Re-ID — ResNet-34 Improved v3
#
# **Architecture** : ResNet-34 (BatchNorm + ReLU, Dropout 0.4, AdamW)
# **Improvement over Baseline** : BN/ReLU corrections, weight decay, moderate augmentation (data pipeline via make_dataset)

# %% [markdown]
# ## 1. Setup & data loading

# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), '..'))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, optimizers, callbacks
from sklearn.preprocessing import normalize
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

from src.data import load_data, load_test_pairs, make_dataset

print(f"TensorFlow: {tf.__version__}")
print(f"GPU: {tf.config.list_physical_devices('GPU')}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775903932.190996    4383 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1775903932.727851    4383 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775903934.379314    4383 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# TensorFlow: 2.21.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# W0000 00:00:1775903936.194731    4383 gpu_device.cc:2459] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0a. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.

# %%
PROJECT_ROOT   = os.path.abspath(os.path.join(os.getcwd(), '..'))
DATA_DIR       = os.path.join(PROJECT_ROOT, 'data')
CLEANED_DIR    = os.path.join(DATA_DIR, 'cleaned')
OUTPUT_DIR     = os.path.join(PROJECT_ROOT, 'outputs')
SUBMISSION_DIR = os.path.join(PROJECT_ROOT, 'submissions')
LOG_DIR        = os.path.join(PROJECT_ROOT, 'tensorboards')

IMG_SIZE    = 224
NUM_CLASSES = 31
BATCH_SIZE  = 64
SEED        = 42

MODEL_NAME   = 'resnet34_improved_v3'
AUGMENTATION = 'moderate'
#   'none'     → raw images
#   'light'    → flip horizontal
#   'moderate' → flip + brightness + contrast
#   'heavy'    → flip + rotation + zoom + brightness + contrast

os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(SUBMISSION_DIR, exist_ok=True)
os.makedirs(LOG_DIR, exist_ok=True)

tf.random.set_seed(SEED)
np.random.seed(SEED)

# %%
X_train, y_train = load_data('train')
X_val, y_val     = load_data('val')
X_test, test_filenames = load_data('test')
test_pairs_df = load_test_pairs()

train_ds = make_dataset(X_train, y_train, training=True, augmentation=AUGMENTATION, batch_size=BATCH_SIZE)
val_ds   = make_dataset(X_val, y_val, batch_size=BATCH_SIZE)

print(f"Train: {X_train.shape} | Val: {X_val.shape} | Test: {X_test.shape}")
print(f"Train batches: {len(train_ds)} | Val batches: {len(val_ds)}")
# Out:
# W0000 00:00:1775903940.175285    4383 gpu_device.cc:2459] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0a. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# I0000 00:00:1775903940.359319    4383 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13209 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 5070 Ti, pci bus id: 0000:01:00.0, compute capability: 12.0a
# Train: (1516, 224, 224, 3) | Val: (379, 224, 224, 3) | Test: (371, 224, 224, 3)
# Train batches: 24 | Val batches: 6

# %% [markdown]
# ## 2. ResNet-34 architecture (corrected)
#
# Corrections vs notebook 06 :
# - Conv → **BatchNorm → ReLU** (au lieu de Conv → tanh)
# - Shortcut projection : Conv1x1 → **BatchNorm**
# - **Dropout(0.4)** avant la couche de classification

# %%
def residual_block(x, filters, stride=1):
    shortcut = x

    x = layers.Conv2D(filters, (3, 3), strides=(stride, stride), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, (3, 3), strides=(1, 1), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)

    if stride != 1 or shortcut.shape[-1] != filters:
        shortcut = layers.Conv2D(filters, (1, 1), strides=(stride, stride), padding='valid', use_bias=False)(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Add()([shortcut, x])
    x = layers.ReLU()(x)
    return x


def create_resnet34(input_shape, num_classes):
    inputs = keras.Input(input_shape)
    x = inputs

    # Initial conv + pool
    x = layers.Conv2D(64, (7, 7), strides=(2, 2), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Layer 1: 3 blocks, 64 filters
    for _ in range(3):
        x = residual_block(x, 64)

    # Layer 2: 4 blocks, 128 filters (first with stride 2)
    x = residual_block(x, 128, stride=2)
    for _ in range(3):
        x = residual_block(x, 128)

    # Layer 3: 6 blocks, 256 filters (first with stride 2)
    x = residual_block(x, 256, stride=2)
    for _ in range(5):
        x = residual_block(x, 256)

    # Layer 4: 3 blocks, 512 filters (first with stride 2)
    x = residual_block(x, 512, stride=2)
    for _ in range(2):
        x = residual_block(x, 512)

    # Head
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.4)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    return keras.Model(inputs, outputs)


def build_model():
    return create_resnet34((IMG_SIZE, IMG_SIZE, 3), NUM_CLASSES)

model = build_model()
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 112, 112,  │      9,408 │ input_layer_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 112, 112,  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 112, 112,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 56, 56,    │          0 │ re_lu[0][0]       │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 56, 56,    │     36,864 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 56, 56,    │     36,864 │ re_lu_1[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 56, 56,    │          0 │ max_pooling2d[0]… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 56, 56,    │          0 │ add[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 56, 56,    │     36,864 │ re_lu_2[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 56, 56,    │     36,864 │ re_lu_3[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 56, 56,    │          0 │ re_lu_2[0][0],    │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 56, 56,    │          0 │ add_1[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 56, 56,    │     36,864 │ re_lu_4[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 56, 56,    │     36,864 │ re_lu_5[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 56, 56,    │          0 │ re_lu_4[0][0],    │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 56, 56,    │          0 │ add_2[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 28, 28,    │     73,728 │ re_lu_6[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 28, 28,    │      8,192 │ re_lu_6[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 28, 28,    │    147,456 │ re_lu_7[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 28, 28,    │          0 │ add_3[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 28, 28,    │    147,456 │ re_lu_8[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 28, 28,    │    147,456 │ re_lu_9[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 28, 28,    │          0 │ re_lu_8[0][0],    │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 28, 28,    │          0 │ add_4[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 28, 28,    │    147,456 │ re_lu_10[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 28, 28,    │    147,456 │ re_lu_11[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 28, 28,    │          0 │ re_lu_10[0][0],   │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 28, 28,    │          0 │ add_5[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 28, 28,    │    147,456 │ re_lu_12[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 28, 28,    │    147,456 │ re_lu_13[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 28, 28,    │          0 │ re_lu_12[0][0],   │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 28, 28,    │          0 │ add_6[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 14, 14,    │    294,912 │ re_lu_14[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 14, 14,    │     32,768 │ re_lu_14[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_15[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 14, 14,    │          0 │ add_7[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_16[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_17[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 14, 14,    │          0 │ re_lu_16[0][0],   │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 14, 14,    │          0 │ add_8[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_18[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_19 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_19[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 14, 14,    │          0 │ re_lu_18[0][0],   │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_20 (ReLU)     │ (None, 14, 14,    │          0 │ add_9[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_20[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_21 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_21[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 14, 14,    │          0 │ re_lu_20[0][0],   │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_22 (ReLU)     │ (None, 14, 14,    │          0 │ add_10[0][0]      │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_22[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_23 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_23[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 14, 14,    │          0 │ re_lu_22[0][0],   │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_24 (ReLU)     │ (None, 14, 14,    │          0 │ add_11[0][0]      │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_24[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_25 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_25[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 14, 14,    │          0 │ re_lu_24[0][0],   │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_26 (ReLU)     │ (None, 14, 14,    │          0 │ add_12[0][0]      │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 7, 7, 512) │  1,179,648 │ re_lu_26[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_27 (ReLU)     │ (None, 7, 7, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 7, 7, 512) │    131,072 │ re_lu_26[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 7, 7, 512) │  2,359,296 │ re_lu_27[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 7, 7, 512) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_28 (ReLU)     │ (None, 7, 7, 512) │          0 │ add_13[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 7, 7, 512) │  2,359,296 │ re_lu_28[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_29 (ReLU)     │ (None, 7, 7, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 7, 7, 512) │  2,359,296 │ re_lu_29[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 7, 7, 512) │          0 │ re_lu_28[0][0],   │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_30 (ReLU)     │ (None, 7, 7, 512) │          0 │ add_14[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 7, 7, 512) │  2,359,296 │ re_lu_30[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_31 (ReLU)     │ (None, 7, 7, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 7, 7, 512) │  2,359,296 │ re_lu_31[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 7, 7, 512) │          0 │ re_lu_30[0][0],   │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_32 (ReLU)     │ (None, 7, 7, 512) │          0 │ add_15[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ re_lu_32[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 31)        │     15,903 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 21,317,599 (81.32 MB)
#  Trainable params: 21,300,575 (81.26 MB)
#  Non-trainable params: 17,024 (66.50 KB)

# %% [markdown]
# ## 3. Hyperparameter sweep
#
# On teste plusieurs learning rates, on garde le meilleur.
# L'augmentation est appliquée dans le pipeline de données (`make_dataset`).

# %%
WEIGHT_DECAY = 5e-4

def train_and_eval(lr, run_name):
    m = build_model()
    m.compile(
        optimizer=optimizers.AdamW(learning_rate=lr, weight_decay=WEIGHT_DECAY),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    log_dir = os.path.join(LOG_DIR, MODEL_NAME, run_name)
    hist = m.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[
            callbacks.EarlyStopping(
                monitor='val_loss', patience=20, restore_best_weights=True
            ),
            callbacks.ReduceLROnPlateau(
                monitor='val_loss', factor=0.5, patience=7, min_lr=1e-7, verbose=0
            ),
            callbacks.TensorBoard(log_dir=log_dir),
        ],
        verbose=0
    )
    _, val_acc = m.evaluate(val_ds, verbose=0)
    best_epoch = np.argmin(hist.history['val_loss']) + 1
    print(f"  {run_name}: val_acc={val_acc:.4f} (best epoch={best_epoch})")
    return {'val_acc': val_acc, 'best_epoch': best_epoch, 'hist': hist.history}

# %%
lr_candidates = [1e-3, 5e-4, 1e-4]

results = {}
print(f"=== LR sweep ({MODEL_NAME}) ===")
for lr in lr_candidates:
    run_name = f'lr_{lr}'
    results[run_name] = train_and_eval(lr, run_name)
# Out:
# === LR sweep (resnet34_improved_v3) ===
# I0000 00:00:1775903949.206061    4553 service.cc:153] XLA service 0x7f2f70085a10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1775903949.206122    4553 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 5070 Ti, Compute Capability 12.0a (Driver: 13.2.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.20.0)
# I0000 00:00:1775903949.440661    4553 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1775903950.803049    4553 cuda_dnn.cc:461] Loaded cuDNN version 92000
# I0000 00:00:1775903951.021948    4553 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_25483__.238
# I0000 00:00:1775903959.778278    4553 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# I0000 00:00:1775903962.646152    4550 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_25483__.238
#   lr_0.001: val_acc=0.8707 (best epoch=32)
# I0000 00:00:1775904086.989008    4552 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_80647__.238
# I0000 00:00:1775904093.712041    4550 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_80647__.238
#   lr_0.0005: val_acc=0.8839 (best epoch=46)
# I0000 00:00:1775904243.834195    4550 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_142114__.238
# I0000 00:00:1775904250.270026    4550 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_142114__.238
#   lr_0.0001: val_acc=0.0554 (best epoch=1)

# %%
rows = [{'Config': name, 'Val Accuracy': r['val_acc'], 'Best Epoch': r['best_epoch']}
        for name, r in results.items()]
results_df = pd.DataFrame(rows).sort_values('Val Accuracy', ascending=False).reset_index(drop=True)
display(results_df)

BEST_CONFIG = results_df.iloc[0]['Config']
BEST_LR = float(BEST_CONFIG.split('_')[1])
BEST_EPOCH = int(results_df.iloc[0]['Best Epoch'])
print(f"\nBest: {BEST_CONFIG} → val_acc={results_df.iloc[0]['Val Accuracy']:.4f}")
# Out:
#       Config  Val Accuracy  Best Epoch
# 0  lr_0.0005      0.883905          46
# 1   lr_0.001      0.870712          32
# 2  lr_0.0001      0.055409           1
# Best: lr_0.0005 → val_acc=0.8839

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
for name, r in results.items():
    axes[0].plot(r['hist']['val_loss'],     label=name)
    axes[1].plot(r['hist']['val_accuracy'], label=name)
axes[0].set_title('Val Loss — LR sweep'); axes[0].legend(); axes[0].grid(True)
axes[1].set_title('Val Accuracy — LR sweep'); axes[1].legend(); axes[1].grid(True)
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, f'{MODEL_NAME}_lr_sweep.png'), dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 4. Evaluation (best config)

# %%
model = build_model()
model.compile(
    optimizer=optimizers.AdamW(learning_rate=BEST_LR, weight_decay=WEIGHT_DECAY),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
log_dir = os.path.join(LOG_DIR, MODEL_NAME, f'best_{datetime.now().strftime("%Y%m%d-%H%M%S")}')

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=100,
    callbacks=[
        callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True),
        callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=7, min_lr=1e-7, verbose=1),
        callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
    ],
    verbose=1
)
# Out:
# Epoch 1/100
# I0000 00:00:1775904306.161372    4549 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_177943__.238
# 23/24 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.0709 - loss: 4.4585
# I0000 00:00:1775904312.609373    4549 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_177943__.238
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 21s 439ms/step - accuracy: 0.1055 - loss: 3.9352 - val_accuracy: 0.0449 - val_loss: 4.3104 - learning_rate: 5.0000e-04
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.2348 - loss: 2.9228 - val_accuracy: 0.0554 - val_loss: 6.5185 - learning_rate: 5.0000e-04
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.3707 - loss: 2.3872 - val_accuracy: 0.0554 - val_loss: 10.3578 - learning_rate: 5.0000e-04
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.4314 - loss: 2.0706 - val_accuracy: 0.0607 - val_loss: 13.3852 - learning_rate: 5.0000e-04
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.5310 - loss: 1.7234 - val_accuracy: 0.0897 - val_loss: 4.9864 - learning_rate: 5.0000e-04
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.5871 - loss: 1.5105 - val_accuracy: 0.0660 - val_loss: 7.1873 - learning_rate: 5.0000e-04
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.6247 - loss: 1.3679 - val_accuracy: 0.0633 - val_loss: 8.6095 - learning_rate: 5.0000e-04
# Epoch 8/100
# 23/24 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6581 - loss: 1.1673
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.6511 - loss: 1.1976 - val_accuracy: 0.0897 - val_loss: 11.8006 - learning_rate: 5.0000e-04
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - accuracy: 0.7454 - loss: 0.8944 - val_accuracy: 0.0607 - val_loss: 8.4184 - learning_rate: 2.5000e-04
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.8087 - loss: 0.6571 - val_accuracy: 0.0396 - val_loss: 8.6202 - learning_rate: 2.5000e-04
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.8509 - loss: 0.5189 - val_accuracy: 0.0818 - val_loss: 8.0696 - learning_rate: 2.5000e-04
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.8542 - loss: 0.4863 - val_accuracy: 0.0739 - val_loss: 8.2023 - learning_rate: 2.5000e-04
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.9037 - loss: 0.3563 - val_accuracy: 0.1187 - val_loss: 6.2873 - learning_rate: 2.5000e-04
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.8898 - loss: 0.3769 - val_accuracy: 0.0818 - val_loss: 6.8404 - learning_rate: 2.5000e-04
# Epoch 15/100
# 23/24 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9253 - loss: 0.2700
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.9195 - loss: 0.2773 - val_accuracy: 0.1266 - val_loss: 6.7238 - learning_rate: 2.5000e-04
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.9387 - loss: 0.1908 - val_accuracy: 0.1900 - val_loss: 5.4770 - learning_rate: 1.2500e-04
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.9763 - loss: 0.1060 - val_accuracy: 0.2507 - val_loss: 4.5694 - learning_rate: 1.2500e-04
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.9855 - loss: 0.0709 - val_accuracy: 0.3193 - val_loss: 3.3007 - learning_rate: 1.2500e-04
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.9809 - loss: 0.0679 - val_accuracy: 0.3509 - val_loss: 3.1374 - learning_rate: 1.2500e-04
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.9921 - loss: 0.0421 - val_accuracy: 0.5224 - val_loss: 2.1583 - learning_rate: 1.2500e-04
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.9888 - loss: 0.0441 - val_accuracy: 0.5594 - val_loss: 1.8530 - learning_rate: 1.2500e-04
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.9861 - loss: 0.0531 - val_accuracy: 0.6438 - val_loss: 1.4952 - learning_rate: 1.2500e-04
# Epoch 23/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.9908 - loss: 0.0440 - val_accuracy: 0.7098 - val_loss: 1.2491 - learning_rate: 1.2500e-04
# Epoch 24/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - accuracy: 0.9921 - loss: 0.0391 - val_accuracy: 0.7177 - val_loss: 1.2276 - learning_rate: 1.2500e-04
# Epoch 25/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.9941 - loss: 0.0274 - val_accuracy: 0.8153 - val_loss: 0.8157 - learning_rate: 1.2500e-04
# Epoch 26/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.9974 - loss: 0.0193 - val_accuracy: 0.8206 - val_loss: 0.8654 - learning_rate: 1.2500e-04
# Epoch 27/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.9954 - loss: 0.0175 - val_accuracy: 0.8522 - val_loss: 0.7276 - learning_rate: 1.2500e-04
# Epoch 28/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.9980 - loss: 0.0137 - val_accuracy: 0.8496 - val_loss: 0.7382 - learning_rate: 1.2500e-04
# Epoch 29/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.9967 - loss: 0.0198 - val_accuracy: 0.8311 - val_loss: 0.8530 - learning_rate: 1.2500e-04
# Epoch 30/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.9908 - loss: 0.0339 - val_accuracy: 0.7599 - val_loss: 1.1425 - learning_rate: 1.2500e-04
# Epoch 31/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.9914 - loss: 0.0361 - val_accuracy: 0.7784 - val_loss: 1.1863 - learning_rate: 1.2500e-04
# Epoch 32/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.9861 - loss: 0.0484 - val_accuracy: 0.7942 - val_loss: 0.9277 - learning_rate: 1.2500e-04
# Epoch 33/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.9822 - loss: 0.0507 - val_accuracy: 0.7836 - val_loss: 1.2587 - learning_rate: 1.2500e-04
# Epoch 34/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9915 - loss: 0.0337
# Epoch 34: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.9888 - loss: 0.0462 - val_accuracy: 0.8047 - val_loss: 0.9380 - learning_rate: 1.2500e-04
# Epoch 35/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.9980 - loss: 0.0190 - val_accuracy: 0.8417 - val_loss: 0.7793 - learning_rate: 6.2500e-05
# Epoch 36/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - accuracy: 0.9980 - loss: 0.0156 - val_accuracy: 0.8602 - val_loss: 0.6488 - learning_rate: 6.2500e-05
# Epoch 37/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.9987 - loss: 0.0098 - val_accuracy: 0.8786 - val_loss: 0.6073 - learning_rate: 6.2500e-05
# Epoch 38/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.9987 - loss: 0.0077 - val_accuracy: 0.8654 - val_loss: 0.6635 - learning_rate: 6.2500e-05
# Epoch 39/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.9980 - loss: 0.0090 - val_accuracy: 0.8496 - val_loss: 0.6490 - learning_rate: 6.2500e-05
# Epoch 40/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.9987 - loss: 0.0081 - val_accuracy: 0.8628 - val_loss: 0.6458 - learning_rate: 6.2500e-05
# Epoch 41/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8628 - val_loss: 0.6263 - learning_rate: 6.2500e-05
# Epoch 42/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.8707 - val_loss: 0.6037 - learning_rate: 6.2500e-05
# Epoch 43/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8734 - val_loss: 0.5961 - learning_rate: 6.2500e-05
# Epoch 44/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8786 - val_loss: 0.5863 - learning_rate: 6.2500e-05
# Epoch 45/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.9993 - loss: 0.0045 - val_accuracy: 0.8786 - val_loss: 0.5792 - learning_rate: 6.2500e-05
# Epoch 46/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.8839 - val_loss: 0.5900 - learning_rate: 6.2500e-05
# Epoch 47/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.8786 - val_loss: 0.5971 - learning_rate: 6.2500e-05
# Epoch 48/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.9993 - loss: 0.0030 - val_accuracy: 0.8813 - val_loss: 0.5963 - learning_rate: 6.2500e-05
# Epoch 49/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8813 - val_loss: 0.5861 - learning_rate: 6.2500e-05
# Epoch 50/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8786 - val_loss: 0.6171 - learning_rate: 6.2500e-05
# Epoch 51/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.9993 - loss: 0.0033 - val_accuracy: 0.8918 - val_loss: 0.5807 - learning_rate: 6.2500e-05
# Epoch 52/100
# 23/24 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9990 - loss: 0.0039
# Epoch 52: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.9987 - loss: 0.0048 - val_accuracy: 0.8786 - val_loss: 0.6011 - learning_rate: 6.2500e-05
# Epoch 53/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.8786 - val_loss: 0.5942 - learning_rate: 3.1250e-05
# Epoch 54/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8813 - val_loss: 0.5806 - learning_rate: 3.1250e-05
# Epoch 55/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.9993 - loss: 0.0031 - val_accuracy: 0.8865 - val_loss: 0.5821 - learning_rate: 3.1250e-05
# Epoch 56/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.8865 - val_loss: 0.5813 - learning_rate: 3.1250e-05
# Epoch 57/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8892 - val_loss: 0.5797 - learning_rate: 3.1250e-05
# Epoch 58/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8865 - val_loss: 0.5821 - learning_rate: 3.1250e-05
# Epoch 59/100
# 23/24 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8892 - val_loss: 0.5821 - learning_rate: 3.1250e-05
# Epoch 60/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.9993 - loss: 0.0022 - val_accuracy: 0.8865 - val_loss: 0.5781 - learning_rate: 1.5625e-05
# Epoch 61/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8892 - val_loss: 0.5807 - learning_rate: 1.5625e-05
# Epoch 62/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8865 - val_loss: 0.5808 - learning_rate: 1.5625e-05
# Epoch 63/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.9993 - loss: 0.0019 - val_accuracy: 0.8813 - val_loss: 0.5816 - learning_rate: 1.5625e-05
# Epoch 64/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.8786 - val_loss: 0.5853 - learning_rate: 1.5625e-05
# Epoch 65/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.9993 - loss: 0.0021 - val_accuracy: 0.8839 - val_loss: 0.5876 - learning_rate: 1.5625e-05
# Epoch 66/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8839 - val_loss: 0.5866 - learning_rate: 1.5625e-05
# Epoch 67/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 67: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.8865 - val_loss: 0.5851 - learning_rate: 1.5625e-05
# Epoch 68/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.8865 - val_loss: 0.5846 - learning_rate: 7.8125e-06
# Epoch 69/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8865 - val_loss: 0.5837 - learning_rate: 7.8125e-06
# Epoch 70/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8865 - val_loss: 0.5836 - learning_rate: 7.8125e-06
# Epoch 71/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8865 - val_loss: 0.5835 - learning_rate: 7.8125e-06
# Epoch 72/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8865 - val_loss: 0.5841 - learning_rate: 7.8125e-06
# Epoch 73/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8865 - val_loss: 0.5851 - learning_rate: 7.8125e-06
# Epoch 74/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 74: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8865 - val_loss: 0.5859 - learning_rate: 7.8125e-06
# Epoch 75/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8865 - val_loss: 0.5859 - learning_rate: 3.9063e-06
# Epoch 76/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8865 - val_loss: 0.5857 - learning_rate: 3.9063e-06
# Epoch 77/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.8865 - val_loss: 0.5869 - learning_rate: 3.9063e-06
# Epoch 78/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8892 - val_loss: 0.5866 - learning_rate: 3.9063e-06
# Epoch 79/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8865 - val_loss: 0.5865 - learning_rate: 3.9063e-06
# Epoch 80/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8892 - val_loss: 0.5869 - learning_rate: 3.9063e-06

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(history.history['loss'],     label='Train')
axes[0].plot(history.history['val_loss'], label='Val')
axes[0].set_xlabel('Epoch'); axes[0].set_ylabel('Loss')
axes[0].set_title(f'{MODEL_NAME} — Loss'); axes[0].legend(); axes[0].grid(True)

axes[1].plot(history.history['accuracy'],     label='Train')
axes[1].plot(history.history['val_accuracy'], label='Val')
axes[1].set_xlabel('Epoch'); axes[1].set_ylabel('Accuracy')
axes[1].set_title(f'{MODEL_NAME} — Accuracy'); axes[1].legend(); axes[1].grid(True)

plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, f'{MODEL_NAME}_history.png'), dpi=150, bbox_inches='tight')
plt.show()

# %%
train_loss, train_acc = model.evaluate(train_ds, verbose=0)
val_loss, val_acc     = model.evaluate(val_ds, verbose=0)

print(f"{MODEL_NAME} (best LR={BEST_LR}):")
print(f"  Train — Loss: {train_loss:.4f}, Acc: {train_acc:.4f}")
print(f"  Val   — Loss: {val_loss:.4f}, Acc: {val_acc:.4f}")
# Out:
# resnet34_improved_v3 (best LR=0.0005):
#   Train — Loss: 0.0001, Acc: 1.0000
#   Val   — Loss: 0.5781, Acc: 0.8865

# %%
y_val_pred = model.predict(val_ds, verbose=0).argmax(axis=1)

cm = confusion_matrix(y_val, y_val_pred)
fig, ax = plt.subplots(figsize=(12, 10))
ConfusionMatrixDisplay(cm).plot(ax=ax, cmap='Blues', colorbar=False)
ax.set_title(f'{MODEL_NAME} — Confusion Matrix (val)')
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, f'{MODEL_NAME}_confusion.png'), dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 5. Kaggle submission

# %%
X_all = np.concatenate([X_train, X_val])
y_all = np.concatenate([y_train, y_val])
all_ds = make_dataset(X_all, y_all, training=True, augmentation=AUGMENTATION, batch_size=BATCH_SIZE)

print(f"Retraining on full dataset ({len(X_all)} images) for {BEST_EPOCH} epochs")

final_model = build_model()
final_model.compile(
    optimizer=optimizers.AdamW(learning_rate=BEST_LR, weight_decay=WEIGHT_DECAY),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

final_log = os.path.join(LOG_DIR, MODEL_NAME, f'final_{datetime.now().strftime("%Y%m%d-%H%M%S")}')
final_model.fit(
    all_ds,
    epochs=BEST_EPOCH,
    callbacks=[callbacks.TensorBoard(log_dir=final_log)],
    verbose=1
)
print(f"Final train acc: {final_model.evaluate(all_ds, verbose=0)[1]:.4f}")
# Out:
# Retraining on full dataset (1895 images) for 46 epochs
# Epoch 1/46
# I0000 00:00:1775904574.297760    4553 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_2227373__.238
# 29/30 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.0834 - loss: 4.0947
# I0000 00:00:1775904582.078166    4553 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_2227373__.238
# I0000 00:00:1775904584.417896   24085 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_MatMul_6', 16 bytes spill stores, 16 bytes spill loads
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 23s 371ms/step - accuracy: 0.1303 - loss: 3.6111
# Epoch 2/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.3024 - loss: 2.7013
# Epoch 3/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.4301 - loss: 2.1546
# Epoch 4/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.5383 - loss: 1.7085
# Epoch 5/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.6047 - loss: 1.4233
# Epoch 6/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.6459 - loss: 1.2419
# Epoch 7/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.6823 - loss: 1.1399
# Epoch 8/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.7356 - loss: 0.9079
# Epoch 9/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.7831 - loss: 0.7571
# Epoch 10/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.8063 - loss: 0.6501
# Epoch 11/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.8369 - loss: 0.5228
# Epoch 12/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.8517 - loss: 0.4745
# Epoch 13/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.8596 - loss: 0.4501
# Epoch 14/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.8923 - loss: 0.3561
# Epoch 15/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9077 - loss: 0.3103
# Epoch 16/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9240 - loss: 0.2704
# Epoch 17/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9488 - loss: 0.1759
# Epoch 18/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9504 - loss: 0.1722
# Epoch 19/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9557 - loss: 0.1387
# Epoch 20/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9694 - loss: 0.1018
# Epoch 21/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9662 - loss: 0.1122
# Epoch 22/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9763 - loss: 0.0747
# Epoch 23/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9736 - loss: 0.0781
# Epoch 24/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9588 - loss: 0.1337
# Epoch 25/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9625 - loss: 0.1293
# Epoch 26/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9551 - loss: 0.1435
# Epoch 27/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9520 - loss: 0.1524
# Epoch 28/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9578 - loss: 0.1298
# Epoch 29/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.9747 - loss: 0.0719
# Epoch 30/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9652 - loss: 0.1118
# Epoch 31/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9678 - loss: 0.0991
# Epoch 32/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9784 - loss: 0.0703
# Epoch 33/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9842 - loss: 0.0476
# Epoch 34/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9826 - loss: 0.0585
# Epoch 35/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9689 - loss: 0.1181
# Epoch 36/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9726 - loss: 0.0963
# Epoch 37/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9799 - loss: 0.0664
# Epoch 38/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9842 - loss: 0.0544
# Epoch 39/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9910 - loss: 0.0333
# Epoch 40/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9947 - loss: 0.0217
# Epoch 41/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9947 - loss: 0.0276
# Epoch 42/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.9921 - loss: 0.0229
# Epoch 43/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9942 - loss: 0.0200
# Epoch 44/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9937 - loss: 0.0210
# Epoch 45/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9905 - loss: 0.0305
# Epoch 46/46
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9858 - loss: 0.0590
# Final train acc: 0.7499

# %%
embedding_model = keras.Model(
    inputs=final_model.input,
    outputs=final_model.layers[-2].output,
    name=f'{MODEL_NAME}_embedding'
)

test_embeddings = embedding_model.predict(X_test, batch_size=BATCH_SIZE, verbose=1)
test_embeddings_norm = normalize(test_embeddings, axis=1)
print(f"Embedding shape: {test_embeddings_norm.shape}")

fname_to_idx = {fname: i for i, fname in enumerate(test_filenames)}
query_idx   = test_pairs_df['query_image'].map(fname_to_idx).values
gallery_idx = test_pairs_df['gallery_image'].map(fname_to_idx).values

similarities = np.clip(
    np.sum(test_embeddings_norm[query_idx] * test_embeddings_norm[gallery_idx], axis=1),
    0, 1
)

submission = pd.DataFrame({'row_id': test_pairs_df['row_id'], 'similarity': similarities})
submission_path = os.path.join(SUBMISSION_DIR, f'submission_{MODEL_NAME}.csv')
submission.to_csv(submission_path, index=False)
print(f"Saved: {submission_path}")
display(submission.head())
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 355ms/step
# Embedding shape: (371, 512)
# Saved: /home/franck/kaggle_jaguar_classification/submissions/submission_resnet34_improved_v3.csv
#    row_id  similarity
# 0       0    0.765536
# 1       1    0.764058
# 2       2    0.755250
# 3       3    0.621263
# 4       4    0.801958

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.hist(similarities, bins=50, color='steelblue', edgecolor='black')
ax.axvline(similarities.mean(), color='red', linestyle='--', label=f'Mean: {similarities.mean():.3f}')
ax.set_xlabel('Similarity score'); ax.set_ylabel('Frequency')
ax.set_title(f'Similarity distribution — {MODEL_NAME}')
ax.legend()
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, f'{MODEL_NAME}_similarity.png'), dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 6. Summary

# %%
print(f"""
ResNet-34 improved v3:
  Train - Loss: {train_loss:.4f}, Acc: {train_acc:.4f}
  Val   - Loss: {val_loss:.4f}, Acc: {val_acc:.4f}
  Best epoch: {BEST_EPOCH}
  Embedding dim: {test_embeddings.shape[1]}
  Régularisation: AdamW (wd={WEIGHT_DECAY}), Dropout(0.4)
  Augmentation: {AUGMENTATION} (data pipeline via make_dataset)

vs ResNet-34 baseline (notebook 06):
  Train: 0.9037, Val: 0.8100
  (tanh, pas de BN, pas de regularisation, 50 epochs)

Submission -> {submission_path}
""")
# Out:
# ResNet-34 improved v3:
#   Train - Loss: 0.0001, Acc: 1.0000
#   Val   - Loss: 0.5781, Acc: 0.8865
#   Best epoch: 46
#   Embedding dim: 512
#   Régularisation: AdamW (wd=0.0005), Dropout(0.4)
#   Augmentation: moderate (data pipeline via make_dataset)
#
# vs ResNet-34 baseline (notebook 06):
#   Train: 0.9037, Val: 0.8100
#   (tanh, pas de BN, pas de regularisation, 50 epochs)
#
# Submission -> /home/franck/kaggle_jaguar_classification/submissions/submission_resnet34_improved_v3.csv

# %% [markdown]
# ## 7. Observations & Verdict

# %% [markdown]
# ### Results
#
# | Métrique | Train | Val |
# |----------|-------|-----|
# | Accuracy | TODO  | TODO |
# | Loss     | TODO  | TODO |
# | Overfitting ? | — | TODO |
# | Kaggle Score (public) | — | TODO |
# | Kaggle Score (private) | — | TODO |
#
# ### Analysis
#
# **Architecture (vs baseline notebook 06) :**
# - Remplacement de `tanh` par `BatchNorm → ReLU` : normalise les activations à chaque bloc, stabilise l'entraînement et accélère la convergence
# - Shortcut projection avec `Conv1x1 → BatchNorm` : garantit la compatibilité des dimensions dans les residual connections
# - `Dropout(0.4)` avant la couche de classification : régularisation pour réduire l'overfitting
# - `AdamW` avec `weight_decay=5e-4` : découple la régularisation L2 de l'optimiseur, plus efficace qu'Adam classique
#
# **Hyperparamètres du LR sweep :**
# - `lr=1e-2` : souvent trop élevé pour un ResNet, risque de divergence ou d'instabilité
# - `lr=1e-3` : valeur classique pour AdamW, bon compromis vitesse/stabilité
# - `lr=1e-4` : convergence plus lente mais potentiellement plus stable sur des données limitées
# - L'hyperparamètre le plus influent est le learning rate : un LR trop élevé empêche la convergence, un LR trop faible ralentit inutilement l'apprentissage
#
# **Overfitting / Underfitting :**
# - Le Dropout(0.4) + AdamW (weight_decay) devraient réduire l'overfitting observé dans la baseline (train=0.90 vs val=0.81)
# - L'EarlyStopping (patience=10) et le ReduceLROnPlateau évitent un surapprentissage prolongé
# - Si le gap train/val reste élevé → augmenter le dropout ou le weight decay
#
# ### Verdict
#
# - [ ] Improvable -> Instructions pour v3 : tester Dropout(0.5), augmentation `heavy`, fine-tuning d'un ResNet34 pré-entraîné (transfer learning)
# - [ ] Not Improvable -> Ceiling reached, why ?
# - [ ] Dead-end -> We ff this architecture, why ?
#
# ### Interpretation
#
# _Free Space : On note ce qu'on a à dire sur ce notebook, servira pour la soutenance._
