# %% [markdown]
# # Jaguar Re-ID — ResNet-34 Improved v3
#
# **Architecture** : ResNet-34 (BatchNorm + ReLU, Dropout 0.4, AdamW)
# **Improvement over Baseline** : BN/ReLU corrections, weight decay, moderate augmentation (data pipeline via make_dataset)

# %% [markdown]
# ## 1. Setup & data loading

# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), '..'))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, optimizers, callbacks
from sklearn.preprocessing import normalize
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

from src.data import load_data, load_test_pairs, make_dataset

print(f"TensorFlow: {tf.__version__}")
print(f"GPU: {tf.config.list_physical_devices('GPU')}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775905076.268147   30124 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1775905076.298864   30124 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775905077.124235   30124 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# TensorFlow: 2.21.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# W0000 00:00:1775905078.036506   30124 gpu_device.cc:2459] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0a. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.

# %%
PROJECT_ROOT   = os.path.abspath(os.path.join(os.getcwd(), '..'))
DATA_DIR       = os.path.join(PROJECT_ROOT, 'data')
CLEANED_DIR    = os.path.join(DATA_DIR, 'cleaned')
OUTPUT_DIR     = os.path.join(PROJECT_ROOT, 'outputs')
SUBMISSION_DIR = os.path.join(PROJECT_ROOT, 'submissions')
LOG_DIR        = os.path.join(PROJECT_ROOT, 'tensorboards')

IMG_SIZE    = 224
NUM_CLASSES = 31
BATCH_SIZE  = 64
SEED        = 42

MODEL_NAME   = 'resnet34_improved_v4'
AUGMENTATION = 'heavy'
#   'none'     → raw images
#   'light'    → flip horizontal
#   'moderate' → flip + brightness + contrast
#   'heavy'    → flip + rotation + zoom + brightness + contrast

os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(SUBMISSION_DIR, exist_ok=True)
os.makedirs(LOG_DIR, exist_ok=True)

tf.random.set_seed(SEED)
np.random.seed(SEED)

# %%
X_train, y_train = load_data('train')
X_val, y_val     = load_data('val')
X_test, test_filenames = load_data('test')
test_pairs_df = load_test_pairs()

train_ds = make_dataset(X_train, y_train, training=True, augmentation=AUGMENTATION, batch_size=BATCH_SIZE)
val_ds   = make_dataset(X_val, y_val, batch_size=BATCH_SIZE)

print(f"Train: {X_train.shape} | Val: {X_val.shape} | Test: {X_test.shape}")
print(f"Train batches: {len(train_ds)} | Val batches: {len(val_ds)}")
# Out:
# W0000 00:00:1775905080.363194   30124 gpu_device.cc:2459] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0a. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# I0000 00:00:1775905080.486306   30124 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13209 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 5070 Ti, pci bus id: 0000:01:00.0, compute capability: 12.0a
# Train: (1516, 224, 224, 3) | Val: (379, 224, 224, 3) | Test: (371, 224, 224, 3)
# Train batches: 24 | Val batches: 6

# %% [markdown]
# ## 2. ResNet-34 architecture (corrected)
#
# Corrections vs notebook 06 :
# - Conv → **BatchNorm → ReLU** (au lieu de Conv → tanh)
# - Shortcut projection : Conv1x1 → **BatchNorm**
# - **Dropout(0.4)** avant la couche de classification

# %%
def residual_block(x, filters, stride=1):
    shortcut = x

    x = layers.Conv2D(filters, (3, 3), strides=(stride, stride), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, (3, 3), strides=(1, 1), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)

    if stride != 1 or shortcut.shape[-1] != filters:
        shortcut = layers.Conv2D(filters, (1, 1), strides=(stride, stride), padding='valid', use_bias=False)(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Add()([shortcut, x])
    x = layers.ReLU()(x)
    return x


def create_resnet34(input_shape, num_classes):
    inputs = keras.Input(input_shape)
    x = inputs

    # Initial conv + pool
    x = layers.Conv2D(64, (7, 7), strides=(2, 2), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Layer 1: 3 blocks, 64 filters
    for _ in range(3):
        x = residual_block(x, 64)

    # Layer 2: 4 blocks, 128 filters (first with stride 2)
    x = residual_block(x, 128, stride=2)
    for _ in range(3):
        x = residual_block(x, 128)

    # Layer 3: 6 blocks, 256 filters (first with stride 2)
    x = residual_block(x, 256, stride=2)
    for _ in range(5):
        x = residual_block(x, 256)

    # Layer 4: 3 blocks, 512 filters (first with stride 2)
    x = residual_block(x, 512, stride=2)
    for _ in range(2):
        x = residual_block(x, 512)

    # Head
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.4)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    return keras.Model(inputs, outputs)


def build_model():
    return create_resnet34((IMG_SIZE, IMG_SIZE, 3), NUM_CLASSES)

model = build_model()
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 112, 112,  │      9,408 │ input_layer_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 112, 112,  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 112, 112,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 56, 56,    │          0 │ re_lu[0][0]       │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 56, 56,    │     36,864 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 56, 56,    │     36,864 │ re_lu_1[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 56, 56,    │          0 │ max_pooling2d[0]… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 56, 56,    │          0 │ add[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 56, 56,    │     36,864 │ re_lu_2[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 56, 56,    │     36,864 │ re_lu_3[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 56, 56,    │          0 │ re_lu_2[0][0],    │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 56, 56,    │          0 │ add_1[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 56, 56,    │     36,864 │ re_lu_4[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 56, 56,    │     36,864 │ re_lu_5[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 56, 56,    │          0 │ re_lu_4[0][0],    │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 56, 56,    │          0 │ add_2[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 28, 28,    │     73,728 │ re_lu_6[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 28, 28,    │      8,192 │ re_lu_6[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 28, 28,    │    147,456 │ re_lu_7[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 28, 28,    │          0 │ add_3[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 28, 28,    │    147,456 │ re_lu_8[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 28, 28,    │    147,456 │ re_lu_9[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 28, 28,    │          0 │ re_lu_8[0][0],    │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 28, 28,    │          0 │ add_4[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 28, 28,    │    147,456 │ re_lu_10[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 28, 28,    │    147,456 │ re_lu_11[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 28, 28,    │          0 │ re_lu_10[0][0],   │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 28, 28,    │          0 │ add_5[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 28, 28,    │    147,456 │ re_lu_12[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 28, 28,    │    147,456 │ re_lu_13[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 28, 28,    │          0 │ re_lu_12[0][0],   │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 28, 28,    │          0 │ add_6[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 14, 14,    │    294,912 │ re_lu_14[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 14, 14,    │     32,768 │ re_lu_14[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_15[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 14, 14,    │          0 │ add_7[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_16[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_17[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 14, 14,    │          0 │ re_lu_16[0][0],   │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 14, 14,    │          0 │ add_8[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_18[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_19 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_19[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 14, 14,    │          0 │ re_lu_18[0][0],   │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_20 (ReLU)     │ (None, 14, 14,    │          0 │ add_9[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_20[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_21 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_21[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 14, 14,    │          0 │ re_lu_20[0][0],   │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_22 (ReLU)     │ (None, 14, 14,    │          0 │ add_10[0][0]      │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_22[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_23 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_23[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 14, 14,    │          0 │ re_lu_22[0][0],   │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_24 (ReLU)     │ (None, 14, 14,    │          0 │ add_11[0][0]      │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_24[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_25 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 14, 14,    │    589,824 │ re_lu_25[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 14, 14,    │          0 │ re_lu_24[0][0],   │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_26 (ReLU)     │ (None, 14, 14,    │          0 │ add_12[0][0]      │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 7, 7, 512) │  1,179,648 │ re_lu_26[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_27 (ReLU)     │ (None, 7, 7, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 7, 7, 512) │    131,072 │ re_lu_26[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 7, 7, 512) │  2,359,296 │ re_lu_27[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 7, 7, 512) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_28 (ReLU)     │ (None, 7, 7, 512) │          0 │ add_13[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 7, 7, 512) │  2,359,296 │ re_lu_28[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_29 (ReLU)     │ (None, 7, 7, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 7, 7, 512) │  2,359,296 │ re_lu_29[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 7, 7, 512) │          0 │ re_lu_28[0][0],   │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_30 (ReLU)     │ (None, 7, 7, 512) │          0 │ add_14[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 7, 7, 512) │  2,359,296 │ re_lu_30[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_31 (ReLU)     │ (None, 7, 7, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 7, 7, 512) │  2,359,296 │ re_lu_31[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 7, 7, 512) │          0 │ re_lu_30[0][0],   │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_32 (ReLU)     │ (None, 7, 7, 512) │          0 │ add_15[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ re_lu_32[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 31)        │     15,903 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 21,317,599 (81.32 MB)
#  Trainable params: 21,300,575 (81.26 MB)
#  Non-trainable params: 17,024 (66.50 KB)

# %% [markdown]
# ## 3. Hyperparameter sweep
#
# On teste plusieurs learning rates, on garde le meilleur.
# L'augmentation est appliquée dans le pipeline de données (`make_dataset`).

# %%
WEIGHT_DECAY = 5e-4

def train_and_eval(lr, run_name):
    m = build_model()
    m.compile(
        optimizer=optimizers.AdamW(learning_rate=lr, weight_decay=WEIGHT_DECAY),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    log_dir = os.path.join(LOG_DIR, MODEL_NAME, run_name)
    hist = m.fit(
        train_ds,
        validation_data=val_ds,
        epochs=100,
        callbacks=[
            callbacks.EarlyStopping(
                monitor='val_loss', patience=20, restore_best_weights=True
            ),
            callbacks.ReduceLROnPlateau(
                monitor='val_loss', factor=0.5, patience=7, min_lr=1e-7, verbose=0
            ),
            callbacks.TensorBoard(log_dir=log_dir),
        ],
        verbose=0
    )
    _, val_acc = m.evaluate(val_ds, verbose=0)
    best_epoch = np.argmin(hist.history['val_loss']) + 1
    print(f"  {run_name}: val_acc={val_acc:.4f} (best epoch={best_epoch})")
    return {'val_acc': val_acc, 'best_epoch': best_epoch, 'hist': hist.history}

# %%
lr_candidates = [1e-3, 5e-4, 1e-4]

results = {}
print(f"=== LR sweep ({MODEL_NAME}) ===")
for lr in lr_candidates:
    run_name = f'lr_{lr}'
    results[run_name] = train_and_eval(lr, run_name)
# Out:
# === LR sweep (resnet34_improved_v4) ===
# I0000 00:00:1775905089.490009   30291 service.cc:153] XLA service 0x7fb750074da0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1775905089.490066   30291 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 5070 Ti, Compute Capability 12.0a (Driver: 13.2.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.20.0)
# I0000 00:00:1775905089.783424   30291 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1775905090.830138   30291 cuda_dnn.cc:461] Loaded cuDNN version 92000
# I0000 00:00:1775905091.032208   30291 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_25722__.238
# I0000 00:00:1775905099.895269   30291 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# I0000 00:00:1775905102.156876   30290 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_25722__.238
#   lr_0.001: val_acc=0.8971 (best epoch=80)
# I0000 00:00:1775905355.060978   30293 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_100880__.238
# I0000 00:00:1775905361.970876   30290 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_100880__.238
#   lr_0.0005: val_acc=0.9077 (best epoch=45)
# I0000 00:00:1775905527.753797   30290 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_159378__.238
# I0000 00:00:1775905534.655869   30291 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_159378__.238
#   lr_0.0001: val_acc=0.0897 (best epoch=1)

# %%
rows = [{'Config': name, 'Val Accuracy': r['val_acc'], 'Best Epoch': r['best_epoch']}
        for name, r in results.items()]
results_df = pd.DataFrame(rows).sort_values('Val Accuracy', ascending=False).reset_index(drop=True)
display(results_df)

BEST_CONFIG = results_df.iloc[0]['Config']
BEST_LR = float(BEST_CONFIG.split('_')[1])
BEST_EPOCH = int(results_df.iloc[0]['Best Epoch'])
print(f"\nBest: {BEST_CONFIG} → val_acc={results_df.iloc[0]['Val Accuracy']:.4f}")
# Out:
#       Config  Val Accuracy  Best Epoch
# 0  lr_0.0005      0.907652          45
# 1   lr_0.001      0.897098          80
# 2  lr_0.0001      0.089710           1
# Best: lr_0.0005 → val_acc=0.9077

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
for name, r in results.items():
    axes[0].plot(r['hist']['val_loss'],     label=name)
    axes[1].plot(r['hist']['val_accuracy'], label=name)
axes[0].set_title('Val Loss — LR sweep'); axes[0].legend(); axes[0].grid(True)
axes[1].set_title('Val Accuracy — LR sweep'); axes[1].legend(); axes[1].grid(True)
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, f'{MODEL_NAME}_lr_sweep.png'), dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 4. Evaluation (best config)

# %%
model = build_model()
model.compile(
    optimizer=optimizers.AdamW(learning_rate=BEST_LR, weight_decay=WEIGHT_DECAY),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
log_dir = os.path.join(LOG_DIR, MODEL_NAME, f'best_{datetime.now().strftime("%Y%m%d-%H%M%S")}')

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=100,
    callbacks=[
        callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True),
        callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=7, min_lr=1e-7, verbose=1),
        callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1),
    ],
    verbose=1
)
# Out:
# Epoch 1/100
# I0000 00:00:1775905596.313813   30291 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_195207__.238
# 23/24 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.0680 - loss: 4.3822
# I0000 00:00:1775905603.192143   30294 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_195207__.238
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 21s 403ms/step - accuracy: 0.0917 - loss: 4.0103 - val_accuracy: 0.0897 - val_loss: 9.1252 - learning_rate: 5.0000e-04
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.1794 - loss: 3.1980 - val_accuracy: 0.0897 - val_loss: 48.0683 - learning_rate: 5.0000e-04
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.2790 - loss: 2.6977 - val_accuracy: 0.0897 - val_loss: 34.7632 - learning_rate: 5.0000e-04
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.3278 - loss: 2.3884 - val_accuracy: 0.0897 - val_loss: 37.4340 - learning_rate: 5.0000e-04
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.3760 - loss: 2.2471 - val_accuracy: 0.0897 - val_loss: 22.5593 - learning_rate: 5.0000e-04
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.4466 - loss: 2.0323 - val_accuracy: 0.0897 - val_loss: 10.1807 - learning_rate: 5.0000e-04
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.4670 - loss: 1.9424 - val_accuracy: 0.0976 - val_loss: 10.9154 - learning_rate: 5.0000e-04
# Epoch 8/100
# 23/24 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4994 - loss: 1.8097
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.5119 - loss: 1.7635 - val_accuracy: 0.1135 - val_loss: 9.1664 - learning_rate: 5.0000e-04
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.5891 - loss: 1.4502 - val_accuracy: 0.1135 - val_loss: 5.3971 - learning_rate: 2.5000e-04
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.6326 - loss: 1.2809 - val_accuracy: 0.1319 - val_loss: 4.8028 - learning_rate: 2.5000e-04
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.6240 - loss: 1.3054 - val_accuracy: 0.1082 - val_loss: 4.9369 - learning_rate: 2.5000e-04
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.6662 - loss: 1.1428 - val_accuracy: 0.0660 - val_loss: 6.8707 - learning_rate: 2.5000e-04
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.6735 - loss: 1.0910 - val_accuracy: 0.0871 - val_loss: 5.1380 - learning_rate: 2.5000e-04
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.7256 - loss: 0.9605 - val_accuracy: 0.0792 - val_loss: 4.5521 - learning_rate: 2.5000e-04
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.7170 - loss: 0.9394 - val_accuracy: 0.1187 - val_loss: 4.4832 - learning_rate: 2.5000e-04
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.7243 - loss: 0.9188 - val_accuracy: 0.1741 - val_loss: 4.9046 - learning_rate: 2.5000e-04
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.7256 - loss: 0.9258 - val_accuracy: 0.1451 - val_loss: 4.6069 - learning_rate: 2.5000e-04
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.7606 - loss: 0.8399 - val_accuracy: 0.2111 - val_loss: 3.9749 - learning_rate: 2.5000e-04
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.7579 - loss: 0.8249 - val_accuracy: 0.2823 - val_loss: 3.4407 - learning_rate: 2.5000e-04
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7619 - loss: 0.8086 - val_accuracy: 0.3325 - val_loss: 3.1997 - learning_rate: 2.5000e-04
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.7672 - loss: 0.7302 - val_accuracy: 0.3404 - val_loss: 2.6523 - learning_rate: 2.5000e-04
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.7823 - loss: 0.7279 - val_accuracy: 0.3720 - val_loss: 2.6246 - learning_rate: 2.5000e-04
# Epoch 23/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.8021 - loss: 0.6664 - val_accuracy: 0.2718 - val_loss: 4.2708 - learning_rate: 2.5000e-04
# Epoch 24/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.8245 - loss: 0.5752 - val_accuracy: 0.4644 - val_loss: 3.8531 - learning_rate: 2.5000e-04
# Epoch 25/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.8120 - loss: 0.6098 - val_accuracy: 0.5224 - val_loss: 2.2996 - learning_rate: 2.5000e-04
# Epoch 26/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.8193 - loss: 0.5902 - val_accuracy: 0.5805 - val_loss: 1.7356 - learning_rate: 2.5000e-04
# Epoch 27/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.8325 - loss: 0.5678 - val_accuracy: 0.5778 - val_loss: 1.8466 - learning_rate: 2.5000e-04
# Epoch 28/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.8344 - loss: 0.5233 - val_accuracy: 0.7520 - val_loss: 1.1088 - learning_rate: 2.5000e-04
# Epoch 29/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.8391 - loss: 0.4863 - val_accuracy: 0.7150 - val_loss: 1.1804 - learning_rate: 2.5000e-04
# Epoch 30/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.8549 - loss: 0.4851 - val_accuracy: 0.6069 - val_loss: 1.8330 - learning_rate: 2.5000e-04
# Epoch 31/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.8542 - loss: 0.4357 - val_accuracy: 0.7441 - val_loss: 0.9986 - learning_rate: 2.5000e-04
# Epoch 32/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.8529 - loss: 0.4557 - val_accuracy: 0.5989 - val_loss: 1.6490 - learning_rate: 2.5000e-04
# Epoch 33/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.8661 - loss: 0.4199 - val_accuracy: 0.6702 - val_loss: 1.5419 - learning_rate: 2.5000e-04
# Epoch 34/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.8753 - loss: 0.4099 - val_accuracy: 0.6438 - val_loss: 1.4609 - learning_rate: 2.5000e-04
# Epoch 35/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.8740 - loss: 0.4133 - val_accuracy: 0.7071 - val_loss: 1.3079 - learning_rate: 2.5000e-04
# Epoch 36/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.8760 - loss: 0.3686 - val_accuracy: 0.5145 - val_loss: 2.0418 - learning_rate: 2.5000e-04
# Epoch 37/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.8918 - loss: 0.3847 - val_accuracy: 0.6385 - val_loss: 1.7887 - learning_rate: 2.5000e-04
# Epoch 38/100
# 23/24 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9016 - loss: 0.3546
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.8865 - loss: 0.3827 - val_accuracy: 0.7071 - val_loss: 1.4232 - learning_rate: 2.5000e-04
# Epoch 39/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.8997 - loss: 0.3010 - val_accuracy: 0.8391 - val_loss: 0.7720 - learning_rate: 1.2500e-04
# Epoch 40/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.9558 - loss: 0.1473 - val_accuracy: 0.8179 - val_loss: 0.7453 - learning_rate: 1.2500e-04
# Epoch 41/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.9604 - loss: 0.1442 - val_accuracy: 0.8760 - val_loss: 0.5922 - learning_rate: 1.2500e-04
# Epoch 42/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.9624 - loss: 0.1255 - val_accuracy: 0.8575 - val_loss: 0.6504 - learning_rate: 1.2500e-04
# Epoch 43/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.9743 - loss: 0.0879 - val_accuracy: 0.8839 - val_loss: 0.5182 - learning_rate: 1.2500e-04
# Epoch 44/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.9716 - loss: 0.0963 - val_accuracy: 0.8918 - val_loss: 0.5700 - learning_rate: 1.2500e-04
# Epoch 45/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.9710 - loss: 0.1090 - val_accuracy: 0.8443 - val_loss: 0.7436 - learning_rate: 1.2500e-04
# Epoch 46/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.9809 - loss: 0.0787 - val_accuracy: 0.8707 - val_loss: 0.6511 - learning_rate: 1.2500e-04
# Epoch 47/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.9730 - loss: 0.0986 - val_accuracy: 0.8918 - val_loss: 0.5287 - learning_rate: 1.2500e-04
# Epoch 48/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.9611 - loss: 0.1208 - val_accuracy: 0.8470 - val_loss: 0.6908 - learning_rate: 1.2500e-04
# Epoch 49/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.9763 - loss: 0.0844 - val_accuracy: 0.9024 - val_loss: 0.5431 - learning_rate: 1.2500e-04
# Epoch 50/100
# 23/24 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9860 - loss: 0.0568
# Epoch 50: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.9782 - loss: 0.0699 - val_accuracy: 0.8786 - val_loss: 0.5753 - learning_rate: 1.2500e-04
# Epoch 51/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.9861 - loss: 0.0556 - val_accuracy: 0.8681 - val_loss: 0.6354 - learning_rate: 6.2500e-05
# Epoch 52/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.9855 - loss: 0.0642 - val_accuracy: 0.8918 - val_loss: 0.5649 - learning_rate: 6.2500e-05
# Epoch 53/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.9842 - loss: 0.0519 - val_accuracy: 0.8918 - val_loss: 0.5419 - learning_rate: 6.2500e-05
# Epoch 54/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.9861 - loss: 0.0570 - val_accuracy: 0.8918 - val_loss: 0.5411 - learning_rate: 6.2500e-05
# Epoch 55/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.9901 - loss: 0.0394 - val_accuracy: 0.8971 - val_loss: 0.5542 - learning_rate: 6.2500e-05
# Epoch 56/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.9901 - loss: 0.0388 - val_accuracy: 0.8997 - val_loss: 0.5827 - learning_rate: 6.2500e-05
# Epoch 57/100
# 23/24 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9906 - loss: 0.0343
# Epoch 57: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.9927 - loss: 0.0316 - val_accuracy: 0.8918 - val_loss: 0.5443 - learning_rate: 6.2500e-05
# Epoch 58/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.9927 - loss: 0.0304 - val_accuracy: 0.8892 - val_loss: 0.5469 - learning_rate: 3.1250e-05
# Epoch 59/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.9894 - loss: 0.0357 - val_accuracy: 0.8945 - val_loss: 0.5574 - learning_rate: 3.1250e-05
# Epoch 60/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.9875 - loss: 0.0378 - val_accuracy: 0.8997 - val_loss: 0.5444 - learning_rate: 3.1250e-05
# Epoch 61/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.9974 - loss: 0.0228 - val_accuracy: 0.9050 - val_loss: 0.5354 - learning_rate: 3.1250e-05
# Epoch 62/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.9934 - loss: 0.0302 - val_accuracy: 0.8971 - val_loss: 0.5583 - learning_rate: 3.1250e-05
# Epoch 63/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.9947 - loss: 0.0283 - val_accuracy: 0.9024 - val_loss: 0.5405 - learning_rate: 3.1250e-05

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(history.history['loss'],     label='Train')
axes[0].plot(history.history['val_loss'], label='Val')
axes[0].set_xlabel('Epoch'); axes[0].set_ylabel('Loss')
axes[0].set_title(f'{MODEL_NAME} — Loss'); axes[0].legend(); axes[0].grid(True)

axes[1].plot(history.history['accuracy'],     label='Train')
axes[1].plot(history.history['val_accuracy'], label='Val')
axes[1].set_xlabel('Epoch'); axes[1].set_ylabel('Accuracy')
axes[1].set_title(f'{MODEL_NAME} — Accuracy'); axes[1].legend(); axes[1].grid(True)

plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, f'{MODEL_NAME}_history.png'), dpi=150, bbox_inches='tight')
plt.show()

# %%
train_loss, train_acc = model.evaluate(train_ds, verbose=0)
val_loss, val_acc     = model.evaluate(val_ds, verbose=0)

print(f"{MODEL_NAME} (best LR={BEST_LR}):")
print(f"  Train — Loss: {train_loss:.4f}, Acc: {train_acc:.4f}")
print(f"  Val   — Loss: {val_loss:.4f}, Acc: {val_acc:.4f}")
# Out:
# resnet34_improved_v4 (best LR=0.0005):
#   Train — Loss: 0.0625, Acc: 0.9868
#   Val   — Loss: 0.5182, Acc: 0.8839

# %%
y_val_pred = model.predict(val_ds, verbose=0).argmax(axis=1)

cm = confusion_matrix(y_val, y_val_pred)
fig, ax = plt.subplots(figsize=(12, 10))
ConfusionMatrixDisplay(cm).plot(ax=ax, cmap='Blues', colorbar=False)
ax.set_title(f'{MODEL_NAME} — Confusion Matrix (val)')
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, f'{MODEL_NAME}_confusion.png'), dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 5. Kaggle submission

# %%
X_all = np.concatenate([X_train, X_val])
y_all = np.concatenate([y_train, y_val])
all_ds = make_dataset(X_all, y_all, training=True, augmentation=AUGMENTATION, batch_size=BATCH_SIZE)

print(f"Retraining on full dataset ({len(X_all)} images) for {BEST_EPOCH} epochs")

final_model = build_model()
final_model.compile(
    optimizer=optimizers.AdamW(learning_rate=BEST_LR, weight_decay=WEIGHT_DECAY),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

final_log = os.path.join(LOG_DIR, MODEL_NAME, f'final_{datetime.now().strftime("%Y%m%d-%H%M%S")}')
final_model.fit(
    all_ds,
    epochs=BEST_EPOCH,
    callbacks=[callbacks.TensorBoard(log_dir=final_log)],
    verbose=1
)
print(f"Final train acc: {final_model.evaluate(all_ds, verbose=0)[1]:.4f}")
# Out:
# Retraining on full dataset (1895 images) for 45 epochs
# Epoch 1/45
# I0000 00:00:1775905827.491914   30294 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1817239__.238
# 29/30 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.0758 - loss: 4.0982
# I0000 00:00:1775905834.148237   30294 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1817239__.238
# I0000 00:00:1775905836.270078   52125 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_MatMul_6', 16 bytes spill stores, 16 bytes spill loads
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 362ms/step - accuracy: 0.1061 - loss: 3.7736
# Epoch 2/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.2016 - loss: 3.0635
# Epoch 3/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.3082 - loss: 2.5445
# Epoch 4/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.3794 - loss: 2.2636
# Epoch 5/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.4580 - loss: 2.0115
# Epoch 6/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.4617 - loss: 1.9189
# Epoch 7/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.5288 - loss: 1.7095
# Epoch 8/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.5562 - loss: 1.6126
# Epoch 9/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.5683 - loss: 1.5442
# Epoch 10/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.6216 - loss: 1.3182
# Epoch 11/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.6596 - loss: 1.1918
# Epoch 12/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.6617 - loss: 1.1662
# Epoch 13/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.7029 - loss: 1.0748
# Epoch 14/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.7272 - loss: 0.9351
# Epoch 15/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.7272 - loss: 1.0003
# Epoch 16/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.7230 - loss: 0.9163
# Epoch 17/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.7472 - loss: 0.8622
# Epoch 18/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.7631 - loss: 0.7860
# Epoch 19/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.7462 - loss: 0.8600
# Epoch 20/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.7668 - loss: 0.7385
# Epoch 21/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.8084 - loss: 0.6613
# Epoch 22/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.8063 - loss: 0.6432
# Epoch 23/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.8084 - loss: 0.6428
# Epoch 24/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.8121 - loss: 0.5955
# Epoch 25/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.8475 - loss: 0.5205
# Epoch 26/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.8591 - loss: 0.4595
# Epoch 27/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.8723 - loss: 0.4485
# Epoch 28/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.8691 - loss: 0.4509
# Epoch 29/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.8491 - loss: 0.4903
# Epoch 30/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.8586 - loss: 0.4734
# Epoch 31/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.8654 - loss: 0.4231
# Epoch 32/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.8760 - loss: 0.4197
# Epoch 33/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9003 - loss: 0.3380
# Epoch 34/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9050 - loss: 0.3223
# Epoch 35/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.8923 - loss: 0.3408
# Epoch 36/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.8966 - loss: 0.3391
# Epoch 37/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9013 - loss: 0.3313
# Epoch 38/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.8992 - loss: 0.3051
# Epoch 39/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9003 - loss: 0.3383
# Epoch 40/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9013 - loss: 0.3222
# Epoch 41/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9203 - loss: 0.2630
# Epoch 42/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9230 - loss: 0.2551
# Epoch 43/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9277 - loss: 0.2502
# Epoch 44/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9277 - loss: 0.2309
# Epoch 45/45
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9293 - loss: 0.2137
# Final train acc: 0.8997

# %%
embedding_model = keras.Model(
    inputs=final_model.input,
    outputs=final_model.layers[-2].output,
    name=f'{MODEL_NAME}_embedding'
)

test_embeddings = embedding_model.predict(X_test, batch_size=BATCH_SIZE, verbose=1)
test_embeddings_norm = normalize(test_embeddings, axis=1)
print(f"Embedding shape: {test_embeddings_norm.shape}")

fname_to_idx = {fname: i for i, fname in enumerate(test_filenames)}
query_idx   = test_pairs_df['query_image'].map(fname_to_idx).values
gallery_idx = test_pairs_df['gallery_image'].map(fname_to_idx).values

similarities = np.clip(
    np.sum(test_embeddings_norm[query_idx] * test_embeddings_norm[gallery_idx], axis=1),
    0, 1
)

submission = pd.DataFrame({'row_id': test_pairs_df['row_id'], 'similarity': similarities})
submission_path = os.path.join(SUBMISSION_DIR, f'submission_{MODEL_NAME}.csv')
submission.to_csv(submission_path, index=False)
print(f"Saved: {submission_path}")
display(submission.head())
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 356ms/step
# Embedding shape: (371, 512)
# Saved: /home/franck/kaggle_jaguar_classification/submissions/submission_resnet34_improved_v4.csv
#    row_id  similarity
# 0       0    0.786863
# 1       1    0.704138
# 2       2    0.604037
# 3       3    0.485788
# 4       4    0.786573

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.hist(similarities, bins=50, color='steelblue', edgecolor='black')
ax.axvline(similarities.mean(), color='red', linestyle='--', label=f'Mean: {similarities.mean():.3f}')
ax.set_xlabel('Similarity score'); ax.set_ylabel('Frequency')
ax.set_title(f'Similarity distribution — {MODEL_NAME}')
ax.legend()
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, f'{MODEL_NAME}_similarity.png'), dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 6. Summary

# %%
print(f"""
ResNet-34 improved v3:
  Train - Loss: {train_loss:.4f}, Acc: {train_acc:.4f}
  Val   - Loss: {val_loss:.4f}, Acc: {val_acc:.4f}
  Best epoch: {BEST_EPOCH}
  Embedding dim: {test_embeddings.shape[1]}
  Régularisation: AdamW (wd={WEIGHT_DECAY}), Dropout(0.4)
  Augmentation: {AUGMENTATION} (data pipeline via make_dataset)

vs ResNet-34 baseline (notebook 06):
  Train: 0.9037, Val: 0.8100
  (tanh, pas de BN, pas de regularisation, 50 epochs)

Submission -> {submission_path}
""")
# Out:
# ResNet-34 improved v3:
#   Train - Loss: 0.0625, Acc: 0.9868
#   Val   - Loss: 0.5182, Acc: 0.8839
#   Best epoch: 45
#   Embedding dim: 512
#   Régularisation: AdamW (wd=0.0005), Dropout(0.4)
#   Augmentation: heavy (data pipeline via make_dataset)
#
# vs ResNet-34 baseline (notebook 06):
#   Train: 0.9037, Val: 0.8100
#   (tanh, pas de BN, pas de regularisation, 50 epochs)
#
# Submission -> /home/franck/kaggle_jaguar_classification/submissions/submission_resnet34_improved_v4.csv

# %% [markdown]
# ## 7. Observations & Verdict

# %% [markdown]
# ### Results
#
# | Métrique | Train | Val |
# |----------|-------|-----|
# | Accuracy | TODO  | TODO |
# | Loss     | TODO  | TODO |
# | Overfitting ? | — | TODO |
# | Kaggle Score (public) | — | TODO |
# | Kaggle Score (private) | — | TODO |
#
# ### Analysis
#
# **Architecture (vs baseline notebook 06) :**
# - Remplacement de `tanh` par `BatchNorm → ReLU` : normalise les activations à chaque bloc, stabilise l'entraînement et accélère la convergence
# - Shortcut projection avec `Conv1x1 → BatchNorm` : garantit la compatibilité des dimensions dans les residual connections
# - `Dropout(0.4)` avant la couche de classification : régularisation pour réduire l'overfitting
# - `AdamW` avec `weight_decay=5e-4` : découple la régularisation L2 de l'optimiseur, plus efficace qu'Adam classique
#
# **Hyperparamètres du LR sweep :**
# - `lr=1e-2` : souvent trop élevé pour un ResNet, risque de divergence ou d'instabilité
# - `lr=1e-3` : valeur classique pour AdamW, bon compromis vitesse/stabilité
# - `lr=1e-4` : convergence plus lente mais potentiellement plus stable sur des données limitées
# - L'hyperparamètre le plus influent est le learning rate : un LR trop élevé empêche la convergence, un LR trop faible ralentit inutilement l'apprentissage
#
# **Overfitting / Underfitting :**
# - Le Dropout(0.4) + AdamW (weight_decay) devraient réduire l'overfitting observé dans la baseline (train=0.90 vs val=0.81)
# - L'EarlyStopping (patience=10) et le ReduceLROnPlateau évitent un surapprentissage prolongé
# - Si le gap train/val reste élevé → augmenter le dropout ou le weight decay
#
# ### Verdict
#
# - [ ] Improvable -> Instructions pour v3 : tester Dropout(0.5), augmentation `heavy`, fine-tuning d'un ResNet34 pré-entraîné (transfer learning)
# - [ ] Not Improvable -> Ceiling reached, why ?
# - [ ] Dead-end -> We ff this architecture, why ?
#
# ### Interpretation
#
# _Free Space : On note ce qu'on a à dire sur ce notebook, servira pour la soutenance._
